# %%
file_path = '/data/projects/11003765/sate/satte/satellite-te/output/DataSetForSaTE100_GrdStation_spaceTE/test_logs/spaceTE_topo-10000_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-32_sample-5_rho-1.0_step-5_quantized-False_compiled-False.csv'

# %%
import pandas as pd
from scipy.io import savemat

df = pd.read_csv(file_path)

column_data = df['runtime'].values

mat_file_path = 'runtime.mat'
savemat(mat_file_path, {'runtime': column_data})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9ef2f2ab939c> in <module>
# ----> 1 import pandas as pd
#       2 from scipy.io import savemat
#       3
#       4 df = pd.read_csv(file_path)
#       5
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

file_iridium = '/data/projects/11003765/sate/satte/satellite-te/output/teal/iridium_IridiumDataSet14day20sec_Int15_teal/test_logs/teal_topo-1_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-1_layer-6_sample-5_rho-1.0_step-5.csv'

file_176 = '/data/projects/11003765/sate/satte/satellite-te/output/teal/starlink_176_ISL_teal_teal/test_logs/teal_topo-1_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-1_layer-6_sample-5_rho-1.0_step-5.csv'

file_500 = '/data/projects/11003765/sate/satte/satellite-te/output/teal/starlink_500_ISL_teal_teal/test_logs/teal_topo-1_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-1_layer-6_sample-5_rho-1.0_step-5.csv'

file_528 = '/data/projects/11003765/sate/satte/satellite-te/output/teal/starlink_528_ISL_teal_teal/test_logs/teal_topo-1_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-1_layer-6_sample-5_rho-1.0_step-5.csv'

df_iridium = pd.read_csv(file_iridium)
df_176 = pd.read_csv(file_176)
df_500 = pd.read_csv(file_500)
df_528 = pd.read_csv(file_528)

mean_runtime_iridium = df_iridium['runtime'].mean()
mean_runtime_176 = df_176['runtime'].mean()
mean_runtime_500 = df_500['runtime'].mean()
mean_runtime_528 = df_528['runtime'].mean()

print(mean_runtime_iridium, mean_runtime_176, mean_runtime_500, mean_runtime_528)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7cbfcc70dfa8> in <module>
# ----> 1 import pandas as pd
#       2
#       3 file_iridium = '/data/projects/11003765/sate/satte/satellite-te/output/teal/iridium_IridiumDataSet14day20sec_Int15_teal/test_logs/teal_topo-1_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-1_layer-6_sample-5_rho-1.0_step-5.csv'
#       4
#       5 file_176 = '/data/projects/11003765/sate/satte/satellite-te/output/teal/starlink_176_ISL_teal_teal/test_logs/teal_topo-1_tsz-None_vr-0.2_lr-0.0001_ep-3_bsz-1_layer-6_sample-5_rho-1.0_step-5.csv'
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import numpy as np

# Given data points
nodes = np.array([66, 176, 396, 528])
times = np.array([0.0181, 0.1026, 0.5916, 1.1467])

# Fit a polynomial to the data with respect to N^2
nodes_squared = (nodes * 2) ** 2
coefficients = np.polyfit(nodes_squared, times, 1)  # Fit a linear polynomial
print(coefficients)
polynomial = np.poly1d(coefficients)

# Estimate the times for 1584 and 4236 nodes
estimate_1584 = polynomial((1584 * 2) ** 2)
estimate_4236 = polynomial((4236 * 2) ** 2)
estimate_asn = polynomial(24806)

estimate_1584, estimate_4236, estimate_asn
# Out:
# [ 1.02853521e-06 -1.96201441e-02]
# (10.302989628598745, 73.80327248505743, 0.0058937003127305446)
